# %% [markdown]
# ### Урок 1

# %% [markdown]
# #### Постройте на одном графике две кривые y(x) для функции двух переменной y(k,x)=cos(k∙x), взяв для одной кривой значение k=1, а для другой – любое другое k, не равное 1.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
x = np.linspace(-10, 10, 100)
plt.plot(x, np.cos(x), color='Blue')
plt.plot(x, np.cos(5*x), color='Red')

# %% [markdown]
# ### Урок 2

# %% [markdown]
# #### Напишите код на Python, реализующий расчет длины вектора, заданного его координатами.

# %%
def length(x, y, z):
    return np.sqrt(x**2 + y**2 + z**2)

x1 = 20
y1 = 20
z1 = 20
length_1 = length(x1, y1, z1)
length_1
# Out:
# 34.64101615137755

# %% [markdown]
# #### Напишите код на Python, реализующий построение графиков: окружности, эллипса, гиперболы.

# %% [markdown]
# #### Окружность

# %%
r = 2
x = np.linspace(-r, r, 100)
plt.plot(x, np.sqrt(r**2 - x**2), color='Blue')
plt.plot(x, - np.sqrt(r**2 - x**2), color='Blue')
plt.axis([-r-0.2, r+0.2, -r-0.2, r+0.2])
# Out:
# [-2.2, 2.2, -2.2, 2.2]

# %% [markdown]
# #### Эллипс

# %%
a = 5
b = 2
x = np.linspace(-a, a, 100)
plt.plot(x, (b/a) * np.sqrt(a**2 - x**2), color='Blue')
plt.plot(x, - (b/a) * np.sqrt(a**2 - x**2), color='Blue')
plt.axis([-a-0.2, a+0.2, -b-0.2, b+0.2])
# Out:
# [-5.2, 5.2, -2.2, 2.2]

# %% [markdown]
# #### Гипербола

# %%
import warnings
warnings.filterwarnings("ignore")

a = 2
b = 2
x = np.linspace(-4, 4, 10000)
plt.plot(x, (b/a) * np.sqrt(x**2 - a**2), color='Blue')
plt.plot(x, - (b/a) * np.sqrt(x**2 - a**2), color='Blue')
plt.axis([-a-2, a+2, -b-2, b+2])
# Out:
# [-4, 4, -4, 4]

# %% [markdown]
# #### Нарисуйте трехмерный график двух параллельных плоскостей.

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5, 5, 0.5)
Y = np.arange(-5, 5, 0.5)
X, Y = np.meshgrid(X, Y)
Z = X + 5*Y
Z1 = X + 5*Y + 10
ax.plot_wireframe(X, Y, Z, color='red')
ax.plot_wireframe(X, Y, Z1, color='blue')
show()

# %% [markdown]
# #### Нарисуйте трехмерный график двух любых поверхностей второго порядка.

# %% [markdown]
# #### Эллиптический параболоид

# %%
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5, 5, 0.5)
Y = np.arange(-5, 5, 0.5)
X, Y = np.meshgrid(X, Y)
Z = X**2 + 5*Y**2
ax.plot_wireframe(X, Y, Z, color='red')
show()

# %% [markdown]
# #### Гиперболический параболоид

# %%
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5, 5, 0.5)
Y = np.arange(-5, 5, 0.5)
X, Y = np.meshgrid(X, Y)
Z = X**2 - Y**2
ax.plot_wireframe(X, Y, Z, color='green')
show()

# %% [markdown]
# #### Прямая

# %%
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5, 5, 0.5)
Y = np.arange(-5, 5, 0.5)
Z = 2*X + 3*Y
ax.plot(X, Y, Z, 'red')
show()

# %% [markdown]
# ### Урок 3

# %% [markdown]
# #### Нарисуйте график функции y(x) = k∙cos(x – a) + b для некоторых (2-3 различных) значений параметров k, a, b

# %%
k = 1
a = 0
b = 0
x = np.linspace(-4 * np.pi, 4 * np.pi, 100)
plt.plot(x, k * np.cos(x - a) + b, color='red')
plt.grid()

# %%
k = 2
a = 0
b = 0
x = np.linspace(-4 * np.pi, 4 * np.pi, 100)
plt.plot(x, k * np.cos(x - a) + b, color='orange')
plt.grid()

# %%
k = 1
a = 1
b = 0
x = np.linspace(-4 * np.pi, 4 * np.pi, 100)
plt.plot(x, k * np.cos(x - a) + b, color='blue')
plt.grid()

# %%
k = 1
a = 0
b = 1
x = np.linspace(-4 * np.pi, 4 * np.pi, 100)
plt.plot(x, k * np.cos(x - a) + b, color='green')
plt.grid()

# %% [markdown]
# #### Напишите код, который будет переводить полярные координаты в декартовы.

# %%
phi, r = np.pi / 3, 2
x = r * np.cos(phi)
y = r * np.sin(phi)
x, y
# Out:
# (1.0000000000000002, 1.7320508075688772)

# %% [markdown]
# #### Напишите код, который будет рисовать график окружности в полярных координатах.

# %%
r = 2
t = np.linspace(0, 2 * np.pi, 100)
x = r * np.cos(t)
y = r * np.sin(t)
plt.plot(x,y)

# %% [markdown]
# #### Решите систему уравнений:
# #### y = x**2 – 1
# #### exp(x) + x∙(1 – y) = 1

# %%
from scipy.optimize import fsolve

def f(p):
    x, y = p
    return (y - x**2 + 1, np.exp(x) + x * (1 - y) - 1)

x1, y1 = fsolve(f, (-2, 5))
x2, y2 = fsolve(f, (2, 5))
x3, y3 = fsolve(f, (4, 15))

print('Решения системы уравнений:')
print(f'Первое решение: {x1}, {y1}')
print(f'Второе решение: {x2}, {y2}')
print(f'Третье решение: {x3}, {y3}')
# Out:
# Решения системы уравнений:
# Первое решение: -1.5818353528958997, 1.5022030836712943
# Второе решение: 2.6181455730830665, 5.854686241850253
# Третье решение: 4.200105841149689, 16.640889076862805

# %% [markdown]
# #### Численное решение системы "вручную"

# %%
a = 5.
n = 1000
x = np.linspace(-a, a, n)
y1 = (x**2 - 1)
y2 = (np.exp(x) + x - 1)/x

solution_x = []
solution_y = []

for i in range(n-1):
    if (y1[i] <= y2[i] <= y1[i+1]) | (y1[i] >= y2[i] >= y1[i+1]):
        solution_x.append(x[i])
        solution_y.append(y2[i])
        
for i in range(len(solution_x)):
    plt.plot(solution_x[i], solution_y[i], 'o', color='red')
plt.plot(x, x**2 - 1, color='blue', linewidth=1.0)
plt.plot(x, (np.exp(x) + x - 1)/x, color='green', linewidth=1.0)
plt.grid(True)
plt.title('Красными точками отмечены решения системы уравнений', color='red');

# %% [markdown]
# #### Решите систему уравнений и неравенств:
# #### y = x**2 – 1
# #### exp(x) + x∙(1 – y) > 1

# %%
a = 5.
n = 100
x = np.linspace(-a, a, n)
y1 = (x**2 - 1)
y2 = ((np.exp(x) + x - 1)/x)

solution_x = []
solution_y = []

for i in range(n-1):
    if y1[i] <= y2[i]:
        solution_x.append(x[i])
        solution_y.append(y1[i])
        
plt.plot(x, (np.exp(x) + x - 1)/x, color='yellow', linewidth=3.0)        
for i in range(len(solution_x)):
    plt.plot(solution_x[i], solution_y[i], 'o', color='red')
plt.plot(x, x**2 - 1, color='blue', linewidth=1.0)
plt.grid(True)
plt.title('Красными точками отмечены решения системы в рамках интервала', color='red');

# %%
print(f'Решения системы в рамках интервала по оси 0X от {-a} до {a} с точностью {n} точек на указанный интервал:')
for i in range(len(solution_x)):
    print(f'Решение номер {i}: {solution_x[i]}, {solution_y[i]}')
# Out:
# Решения системы в рамках интервала по оси 0X от -5.0 до 5.0 с точностью 100 точек на указанный интервал:
# Решение номер 0: -1.5656565656565657, 1.4512804815835123
# Решение номер 1: -1.4646464646464645, 1.1451892664013874
# Решение номер 2: -1.3636363636363638, 0.8595041322314052
# Решение номер 3: -1.2626262626262625, 0.5942250790735637
# Решение номер 4: -1.1616161616161618, 0.3493521069278649
# Решение номер 5: -1.0606060606060606, 0.12488521579430656
# Решение номер 6: -0.9595959595959593, -0.07917559432710997
# Решение номер 7: -0.858585858585859, -0.26283032343638335
# Решение номер 8: -0.7575757575757578, -0.4260789715335167
# Решение номер 9: -0.6565656565656566, -0.5689215386185082
# Решение номер 10: -0.5555555555555554, -0.6913580246913582
# Решение номер 11: -0.45454545454545503, -0.7933884297520657
# Решение номер 12: -0.3535353535353538, -0.8750127538006324
# Решение номер 13: -0.2525252525252526, -0.9362309968370575
# ...
